# %% [markdown]
# ## Test 2

# %% [markdown]
# question 1 -
# answer -

# %%
class student:
    school_name = "UPES"
    def __init_(self , name , age ) :
        self.name = name 
        self.age = age 

s1 = student("abhay", 19)
s2 = student("parav", 99)

print("school:" , s1.student_name)
print("school:" , s2.student_name)


print("student 1:" , s1.name , s1.age)
print("studnet 2:" , s2.name , s2.age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4         self.name = name
#       5         self.age = age
# ----> 7 s1 = student("abhay", 19)
#       8 s2 = student("parav", 99)
#      10 print("school:" , s1.student_name)
#
# TypeError: student() takes no arguments

# %% [markdown]
# question 2 -
# answer 2 -

# %%
class Employee
    company = "ABC Ltd"

    def __init__(self,name, salary):
        self.name = name 
        self.salary = salary

    def show_details(self):
        print("Namea:", self.name, "| salary:" , self.salary, "| comapany:", Employee.company)

    @classmethod
    def change_company(cls,new_name):
            cls.company = new_name

e1 = Employee("abhay:", 98765432)
e2 = Employee("parav:", 2)

print("before change :")
e1.show_details
e2.show_details

Employee.change_company("XYZ Ltd")

print("\nAfter change:")
e1.show_details
e2.show_details
# Out:
#   Cell In[4], line 1
#     class Employee
#                   ^
# SyntaxError: expected ':'

# %% [markdown]
# question 3

# %%
class MathHelper:
    @staticmethod
    def is_even(num):
        return num % 2 == 0

# %% [markdown]
# question 5

# %%
class student:
    """This is a student class"""
print(student.__name__)
print(student.__doc__)
print(student.__module__)
print(student.__dict__)
# Out:
# student
# This is a student class
# __main__
# {'__module__': '__main__', '__firstlineno__': 1, '__doc__': 'This is a student class', '__static_attributes__': (), '__dict__': <attribute '__dict__' of 'student' objects>, '__weakref__': <attribute '__weakref__' of 'student' objects>}

# %% [markdown]
# question 4

# %%
class BankAccount:

    def __init__(self, name, balance):
        self.name = name          # public variable
        self.__balance = balance  # private variable

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def show_balance(self):
        print("Balance:", self.__balance)


# testing
acc = BankAccount("Aman", 1000)

acc.deposit(500)
acc.show_balance()

acc.withdraw(300)
acc.show_balance()

acc.withdraw(2000)   # insufficient case

# %% [markdown]
# question 6

# %%
class Product:

    def __init__(self, name, price):
        self.name = name
        self.price = price

    def __str__(self):
        return f"Product: {self.name}, Price: {self.price}"

    def __add__(self, other):
        return self.price + other.price

    def __eq__(self, other):
        return self.price == other.price


# creating objects
p1 = Product("Laptop", 50000)
p2 = Product("Phone", 30000)
p3 = Product("Tablet", 50000)

# testing
print(p1)
print(p1 + p2)
print(p1 == p3)
print(p1 == p2)
